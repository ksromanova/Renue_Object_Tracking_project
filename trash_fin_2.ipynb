# %%
from ultralytics import YOLO
import motmetrics as mm
import matplotlib.pyplot as plt
from collections import defaultdict
import numpy as np
import cv2
import os
import shutil
import torch
import sys
from time import time
from datetime import timedelta
from PIL import Image
import json

# %%
PATH_VIDEO = 'C:\\Users\\Freo\\Desktop\\kaggle\\test_task\\renew\\data\\videos\\31-03-2024-09%3A34%3A24.mp4'
OUTPUT_VIDEO = 'output_tracked_video.mp4'

path_to_gt = 'C:\\Users\\Freo\\Desktop\\kaggle\\test_task\\renew\\data\\datasets\\mot_dataset\\gt\\gt.txt'  
path_to_tracker_results = 'C:\\Users\\Freo\\Desktop\\kaggle\\test_task\\renew\\mot_results.txt'



path_to_custom_track = 'C:\\Users\\Freo\\Desktop\\kaggle\\test_task\\renew\\data\\models\\ultralytics\\my_track.yaml'

number_frames = 9000

# %%
PATH_MODEL = "C:\\Users\\Freo\\Desktop\\kaggle\\test_task\\renew\\data\\models\\ultralytics\\yolov10x_v2_4_best.pt"

# Проверка доступности GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(f"Using device: {device}")

# Загрузка модели на GPU
model = YOLO(PATH_MODEL, verbose=False).to(device)
# Out:
# Using device: cuda

# %%
def initialize_video(PATH_VIDEO, OUTPUT_VIDEO):
    cap = cv2.VideoCapture(PATH_VIDEO)
    fps = cap.get(cv2.CAP_PROP_FPS)
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(OUTPUT_VIDEO, fourcc, fps, (frame_width, frame_height))
    return cap, out, fps, frame_width, frame_height

# %%
def process_frame(frame, model, track_history):
    frame_np = frame.copy()  # Сохраняем оригинальный numpy array для трекинга
    frame = frame.transpose(2, 0, 1)  # Перестановка осей в порядок CHW
    frame = np.expand_dims(frame, axis=0)  # Добавляем измерение для batch

    frame = torch.from_numpy(frame).float().div(255.0).cuda(non_blocking=True) if device == 'cuda' else torch.from_numpy(frame).float().div(255.0).cpu()

    # Трекинг
    results = model.track(frame_np, persist=True, tracker=path_to_custom_track)
    
    # Проверка наличия идентификаторов треков
    track_ids = results[0].boxes.id.cpu().numpy().astype(int) if results[0].boxes.id is not None else []

    # Получение координат боксов
    boxes = results[0].boxes.xywh.cpu() if results[0].boxes.xywh is not None else []

    # Аннотируем кадр (отрисовываем трекинг)
    annotated_frame = results[0].plot()

    # Сохранение трека для каждого объекта
    for box, track_id in zip(boxes, track_ids):
        x, y, w, h = box
        track = track_history[track_id]
        track.append((float(x), float(y)))  # x, y - центр
        if len(track) > 90:
            track.pop(0)
        
        # Рисуем линии трекинга
        points = np.hstack(track).astype(np.int32).reshape((-1, 1, 2))
        cv2.polylines(annotated_frame, [points], isClosed=False, color=(230, 230, 230), thickness=2)

    return annotated_frame, track_ids, boxes

# %%
cap, out, fps, frame_width, frame_height = initialize_video(PATH_VIDEO, OUTPUT_VIDEO)

# История трекинга
track_history = defaultdict(lambda: [])

# Ограничение на количество кадров для отладки
max_frames = number_frames

# Инициализация счетчика кадров
frame_count = 0

# Подготовка к записи в MOT формат
mot_results = []

# Старт времени после инициализации
start_time = time()

# Обработка видео
while cap.isOpened() and frame_count < max_frames:
    success, frame = cap.read()

    if not success:
        break

    # Приводим кадр к размеру, соответствующему предыдущему кадру
    frame = cv2.resize(frame, (frame_width, frame_height))  # Изменение размера до исходного

    # Обработка кадра
    annotated_frame, track_ids, boxes = process_frame(frame, model, track_history)

    # Запись кадра в выходное видео
    out.write(annotated_frame)

    # Запись данных в формате MOT
    for box, track_id in zip(boxes, track_ids):
        x, y, w, h = box
        
        # Преобразование центра в координаты верхнего левого угла
        x_min = x - w / 2
        y_min = y - h / 2
        
        mot_results.append((frame_count + 1, track_id, x_min, y_min, w, h, 1, 2, 1.0))

    if device == 'cuda':
        # Очистка кэша GPU с синхронизацией
        torch.cuda.synchronize()
        torch.cuda.empty_cache()



    # Увеличение счетчика обработанных кадров
    frame_count += 1

# Остановка времени сразу после последней операции с кадрами
stop_time = time()

# Завершение работы с видео
if out:
    out.release()
cap.release()

# Вычисление времени обработки
total_time = stop_time - start_time
avg_time_per_frame = total_time / frame_count if frame_count > 0 else 0
print(f'''\nСтатистика обработки:
Количество обработанных кадров: {frame_count}
Общее время обработки: {total_time:.2f} секунд
Среднее время обработки одного кадра: {avg_time_per_frame * 1000:.2f} мс

Видео с трекингом сохранено в {OUTPUT_VIDEO}
Результаты трекинга сохранены в mot_results.txt
''')

# Сохранение результатов в файл MOT
with open('mot_results.txt', 'w') as f:
    for result in mot_results:
        f.write(f"{result[0]},{result[1]},{result[2]},{result[3]},{result[4]},{result[5]},{result[6]},{result[7]},{result[8]}\n")
# Out:
# 0: 480x640 1 PET (transparent) (brown), 2 PET (transparent)s, 49.4ms
# Speed: 4.0ms preprocess, 49.4ms inference, 23.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 2 PET (transparent)s, 40.5ms
# Speed: 3.0ms preprocess, 40.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 2 PET (transparent)s, 41.5ms
# Speed: 2.6ms preprocess, 41.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 2 PET (transparent)s, 37.1ms
# Speed: 2.0ms preprocess, 37.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 2 PET (transparent)s, 35.1ms
# Speed: 2.0ms preprocess, 35.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 2 PET (transparent)s, 35.8ms
# Speed: 2.4ms preprocess, 35.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 2 PET (transparent)s, 36.3ms
# Speed: 2.0ms preprocess, 36.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 2 PET (transparent)s, 37.1ms
# Speed: 2.0ms preprocess, 37.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 2 PET (transparent)s, 37.5ms
# Speed: 2.0ms preprocess, 37.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 2 PET (transparent)s, 38.1ms
# Speed: 3.0ms preprocess, 38.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 2 PET (transparent)s, 39.1ms
# Speed: 3.0ms preprocess, 39.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 2 PET (transparent)s, 37.7ms
# Speed: 2.0ms preprocess, 37.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 2 PET (transparent)s, 36.7ms
# Speed: 3.0ms preprocess, 36.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 2 PET (transparent)s, 1 PET (household chemicals), 35.6ms
# Speed: 3.0ms preprocess, 35.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 2 PET (transparent)s, 1 PET (household chemicals), 35.7ms
# Speed: 2.0ms preprocess, 35.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 2 PET (transparent)s, 1 PET (household chemicals), 36.7ms
# Speed: 2.0ms preprocess, 36.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (transparent), 1 PET (household chemicals), 37.4ms
# Speed: 2.0ms preprocess, 37.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (transparent), 1 PET (household chemicals), 35.3ms
# Speed: 3.0ms preprocess, 35.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (transparent), 1 PET (household chemicals), 35.6ms
# Speed: 2.0ms preprocess, 35.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (transparent), 1 PET (household chemicals), 36.5ms
# Speed: 3.0ms preprocess, 36.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent), 1 PET (household chemicals), 35.8ms
# Speed: 3.0ms preprocess, 35.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent), 1 PET (household chemicals), 35.8ms
# Speed: 2.0ms preprocess, 35.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent), 1 PET (household chemicals), 35.2ms
# Speed: 3.0ms preprocess, 35.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent), 1 PET (household chemicals), 35.0ms
# Speed: 3.0ms preprocess, 35.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent), 1 PET (household chemicals), 36.3ms
# Speed: 2.0ms preprocess, 36.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent), 1 PET (household chemicals), 35.6ms
# Speed: 3.0ms preprocess, 35.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent), 1 PET (household chemicals), 35.0ms
# Speed: 2.0ms preprocess, 35.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent), 35.9ms
# Speed: 2.0ms preprocess, 35.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent), 35.4ms
# Speed: 3.0ms preprocess, 35.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent), 36.0ms
# Speed: 3.0ms preprocess, 36.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (transparent), 35.6ms
# Speed: 2.0ms preprocess, 35.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 37.1ms
# Speed: 2.0ms preprocess, 37.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 36.3ms
# Speed: 2.0ms preprocess, 36.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 36.9ms
# Speed: 2.0ms preprocess, 36.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 35.6ms
# Speed: 3.0ms preprocess, 35.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (transparent), 35.0ms
# Speed: 2.0ms preprocess, 35.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (transparent), 36.2ms
# Speed: 2.0ms preprocess, 36.2ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (transparent), 35.8ms
# Speed: 2.0ms preprocess, 35.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (transparent), 35.4ms
# Speed: 3.0ms preprocess, 35.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (transparent), 35.3ms
# Speed: 2.0ms preprocess, 35.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (transparent), 34.9ms
# Speed: 3.0ms preprocess, 34.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (transparent), 36.3ms
# Speed: 2.0ms preprocess, 36.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (transparent), 35.3ms
# Speed: 2.0ms preprocess, 35.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (transparent), 35.7ms
# Speed: 3.0ms preprocess, 35.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (transparent), 35.5ms
# Speed: 3.0ms preprocess, 35.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (transparent), 1 Other plastic, 36.5ms
# Speed: 2.0ms preprocess, 36.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (transparent), 1 Other plastic, 36.5ms
# Speed: 2.0ms preprocess, 36.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (transparent), 2 Other plastics, 36.8ms
# Speed: 2.0ms preprocess, 36.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (transparent), 2 Other plastics, 35.7ms
# Speed: 2.0ms preprocess, 35.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (transparent) (brown)s, 1 PET (transparent), 2 Other plastics, 35.4ms
# Speed: 3.0ms preprocess, 35.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (transparent) (brown)s, 1 PET (transparent), 2 Other plastics, 39.7ms
# Speed: 2.0ms preprocess, 39.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (transparent) (brown)s, 1 PET (transparent), 2 Other plastics, 38.6ms
# Speed: 2.0ms preprocess, 38.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (transparent) (brown)s, 1 PET (transparent), 2 Other plastics, 38.1ms
# Speed: 2.0ms preprocess, 38.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 2 PET (transparent)s, 2 Other plastics, 40.8ms
# Speed: 2.0ms preprocess, 40.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 2 PET (transparent)s, 2 Other plastics, 36.1ms
# Speed: 2.0ms preprocess, 36.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 2 PET (transparent)s, 2 Other plastics, 36.5ms
# Speed: 2.0ms preprocess, 36.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 2 PET (transparent)s, 2 Other plastics, 36.3ms
# Speed: 2.0ms preprocess, 36.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 2 PET (transparent)s, 2 Other plastics, 36.4ms
# Speed: 2.0ms preprocess, 36.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 2 PET (transparent)s, 2 Other plastics, 35.7ms
# Speed: 2.0ms preprocess, 35.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 2 PET (transparent)s, 2 Other plastics, 35.1ms
# Speed: 2.0ms preprocess, 35.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (transparent), 2 Other plastics, 36.5ms
# Speed: 2.7ms preprocess, 36.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (transparent), 2 Other plastics, 36.0ms
# Speed: 2.0ms preprocess, 36.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (transparent), 2 Other plastics, 37.1ms
# Speed: 2.5ms preprocess, 37.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (transparent), 2 Other plastics, 35.5ms
# Speed: 3.0ms preprocess, 35.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (transparent), 2 Other plastics, 36.3ms
# Speed: 3.0ms preprocess, 36.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (transparent), 2 Other plastics, 36.6ms
# Speed: 3.0ms preprocess, 36.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (transparent), 2 Other plastics, 35.0ms
# Speed: 3.0ms preprocess, 35.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (transparent), 2 Other plastics, 35.4ms
# Speed: 3.0ms preprocess, 35.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (transparent), 2 Other plastics, 37.0ms
# Speed: 2.0ms preprocess, 37.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (transparent), 2 Other plastics, 35.6ms
# Speed: 3.0ms preprocess, 35.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (transparent), 2 Other plastics, 37.1ms
# Speed: 2.1ms preprocess, 37.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (transparent), 1 Other plastic, 36.7ms
# Speed: 2.0ms preprocess, 36.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (transparent), 34.5ms
# Speed: 2.0ms preprocess, 34.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (transparent), 36.4ms
# Speed: 3.0ms preprocess, 36.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (transparent), 34.3ms
# Speed: 3.0ms preprocess, 34.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (transparent), 1 PET (household chemicals), 35.6ms
# Speed: 2.0ms preprocess, 35.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent), 1 PET (household chemicals), 36.6ms
# Speed: 2.0ms preprocess, 36.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent), 1 PET (white), 1 PET (household chemicals), 32.0ms
# Speed: 2.0ms preprocess, 32.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent), 2 PET (white)s, 1 PET (household chemicals), 34.5ms
# Speed: 3.0ms preprocess, 34.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (white)s, 1 PET (household chemicals), 36.9ms
# Speed: 3.0ms preprocess, 36.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (white)s, 1 PET (household chemicals), 36.6ms
# Speed: 2.5ms preprocess, 36.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (white)s, 1 PET (flacon), 1 PET (household chemicals), 36.5ms
# Speed: 2.0ms preprocess, 36.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (white)s, 1 PET (flacon), 1 PET (household chemicals), 35.3ms
# Speed: 3.0ms preprocess, 35.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (white)s, 1 PET (flacon), 1 PET (household chemicals), 37.0ms
# Speed: 2.6ms preprocess, 37.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (white)s, 1 PET (flacon), 1 PET (household chemicals), 36.6ms
# Speed: 2.7ms preprocess, 36.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (white)s, 1 PET (flacon), 1 PET (household chemicals), 36.9ms
# Speed: 3.0ms preprocess, 36.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (white)s, 1 PET (flacon), 1 PET (household chemicals), 36.3ms
# Speed: 2.6ms preprocess, 36.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (white)s, 1 PET (flacon), 1 PET (household chemicals), 36.5ms
# Speed: 2.0ms preprocess, 36.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (white)s, 1 PET (flacon), 1 PET (household chemicals), 36.1ms
# Speed: 3.0ms preprocess, 36.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (white)s, 1 PET (flacon), 1 PET (household chemicals), 37.6ms
# Speed: 2.7ms preprocess, 37.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (white)s, 1 PET (flacon), 1 PET (household chemicals), 36.5ms
# Speed: 3.0ms preprocess, 36.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (white)s, 1 PET (flacon), 1 PET (household chemicals), 37.1ms
# Speed: 2.0ms preprocess, 37.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (white)s, 1 PET (flacon), 1 PET (household chemicals), 39.1ms
# Speed: 3.0ms preprocess, 39.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (white)s, 1 PET (flacon), 1 PET (household chemicals), 39.5ms
# Speed: 2.5ms preprocess, 39.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (white)s, 1 PET (flacon), 1 PET (household chemicals), 1 Not plastic, 36.5ms
# Speed: 3.0ms preprocess, 36.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (white)s, 2 PET (flacon)s, 1 PET (household chemicals), 1 Other plastic, 38.8ms
# Speed: 1.6ms preprocess, 38.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (white)s, 2 PET (flacon)s, 1 PET (household chemicals), 1 Other plastic, 1 Not plastic, 37.0ms
# Speed: 2.0ms preprocess, 37.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (white)s, 2 PET (flacon)s, 1 PET (household chemicals), 1 Other plastic, 1 Not plastic, 35.8ms
# Speed: 2.0ms preprocess, 35.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (white)s, 2 PET (flacon)s, 1 PET (household chemicals), 1 Other plastic, 1 Not plastic, 36.4ms
# Speed: 2.0ms preprocess, 36.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (white)s, 2 PET (flacon)s, 1 PET (household chemicals), 1 Other plastic, 1 Not plastic, 36.0ms
# Speed: 2.0ms preprocess, 36.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (white)s, 2 PET (flacon)s, 1 PET (household chemicals), 1 Other plastic, 1 Not plastic, 36.0ms
# Speed: 3.0ms preprocess, 36.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (white)s, 2 PET (flacon)s, 1 Other plastic, 1 Not plastic, 37.8ms
# Speed: 2.6ms preprocess, 37.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (white)s, 2 PET (flacon)s, 1 Other plastic, 1 Not plastic, 35.9ms
# Speed: 2.2ms preprocess, 35.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (white)s, 2 PET (flacon)s, 1 Other plastic, 1 Not plastic, 36.5ms
# Speed: 2.0ms preprocess, 36.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (white), 2 PET (flacon)s, 1 Other plastic, 1 Not plastic, 35.8ms
# Speed: 3.0ms preprocess, 35.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (white), 1 PET (flacon), 1 Other plastic, 1 Not plastic, 35.6ms
# Speed: 3.0ms preprocess, 35.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (flacon), 1 Other plastic, 1 Not plastic, 35.4ms
# Speed: 2.5ms preprocess, 35.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (flacon), 1 Other plastic, 1 Not plastic, 35.0ms
# Speed: 2.7ms preprocess, 35.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (flacon), 1 Other plastic, 1 Not plastic, 34.5ms
# Speed: 3.0ms preprocess, 34.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (flacon), 1 Other plastic, 1 Not plastic, 35.4ms
# Speed: 3.0ms preprocess, 35.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (flacon), 1 Other plastic, 1 Not plastic, 36.1ms
# Speed: 3.0ms preprocess, 36.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (flacon), 1 Other plastic, 1 Not plastic, 35.3ms
# Speed: 2.0ms preprocess, 35.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (flacon), 1 Other plastic, 1 Not plastic, 35.7ms
# Speed: 3.0ms preprocess, 35.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (flacon)s, 1 Other plastic, 1 Not plastic, 36.1ms
# Speed: 2.1ms preprocess, 36.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (flacon)s, 1 Other plastic, 1 Not plastic, 35.5ms
# Speed: 3.0ms preprocess, 35.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (flacon)s, 1 Other plastic, 1 Not plastic, 35.3ms
# Speed: 2.0ms preprocess, 35.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (flacon)s, 1 Other plastic, 1 Not plastic, 37.0ms
# Speed: 2.0ms preprocess, 37.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (flacon)s, 1 PND (household chemicals), 1 Other plastic, 1 Not plastic, 36.4ms
# Speed: 2.0ms preprocess, 36.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (flacon)s, 1 PND (household chemicals), 1 Other plastic, 1 Not plastic, 35.6ms
# Speed: 2.8ms preprocess, 35.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (flacon)s, 1 PND (household chemicals), 1 Other plastic, 1 Not plastic, 36.6ms
# Speed: 2.0ms preprocess, 36.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (flacon)s, 1 PND (household chemicals), 1 Other plastic, 1 Not plastic, 36.0ms
# Speed: 2.0ms preprocess, 36.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (flacon), 1 PND (household chemicals), 35.7ms
# Speed: 2.0ms preprocess, 35.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (flacon), 1 PND (household chemicals), 36.4ms
# Speed: 2.0ms preprocess, 36.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (flacon), 1 PND (household chemicals), 36.7ms
# Speed: 2.0ms preprocess, 36.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (blue), 1 PET (flacon), 1 PND (household chemicals), 35.7ms
# Speed: 2.0ms preprocess, 35.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (blue), 1 PET (flacon), 1 PND (household chemicals), 36.3ms
# Speed: 2.0ms preprocess, 36.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (blue), 1 PET (flacon), 1 PND (household chemicals), 35.0ms
# Speed: 3.0ms preprocess, 35.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (blue), 1 PET (flacon), 1 PND (household chemicals), 1 Other plastic (transparent), 36.1ms
# Speed: 2.0ms preprocess, 36.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (blue), 1 PET (flacon), 1 PND (household chemicals), 1 Other plastic (transparent), 36.0ms
# Speed: 2.0ms preprocess, 36.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (blue), 1 PET (flacon), 1 PND (household chemicals), 1 Other plastic (transparent), 37.6ms
# Speed: 2.0ms preprocess, 37.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (blue), 1 PET (flacon), 1 PND (household chemicals), 1 Other plastic (transparent), 36.7ms
# Speed: 3.0ms preprocess, 36.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (blue), 1 PET (flacon), 2 PND (household chemicals)s, 1 Other plastic (transparent), 37.5ms
# Speed: 2.0ms preprocess, 37.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (blue), 1 PET (flacon), 2 PND (household chemicals)s, 1 Other plastic (transparent), 35.8ms
# Speed: 3.0ms preprocess, 35.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (blue), 1 PET (flacon), 2 PND (household chemicals)s, 1 Other plastic (transparent), 35.1ms
# Speed: 3.0ms preprocess, 35.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (blue), 1 PET (flacon), 2 PND (household chemicals)s, 1 Other plastic (transparent), 38.0ms
# Speed: 3.0ms preprocess, 38.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (blue), 1 PET (flacon), 2 PND (household chemicals)s, 1 Other plastic (transparent), 40.6ms
# Speed: 2.0ms preprocess, 40.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (blue), 1 PET (flacon), 2 PET (household chemicals)s, 2 PND (household chemicals)s, 1 Other plastic (transparent), 38.4ms
# Speed: 2.0ms preprocess, 38.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (blue), 1 PET (flacon), 2 PET (household chemicals)s, 2 PND (household chemicals)s, 1 Other plastic (transparent), 38.9ms
# Speed: 2.0ms preprocess, 38.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (blue), 1 PET (white), 1 PET (flacon), 2 PET (household chemicals)s, 2 PND (household chemicals)s, 1 Other plastic (transparent), 37.2ms
# Speed: 2.0ms preprocess, 37.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (blue), 1 PET (white), 1 PET (flacon), 2 PET (household chemicals)s, 2 PND (household chemicals)s, 1 Other plastic (transparent), 36.3ms
# Speed: 3.0ms preprocess, 36.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (blue), 1 PET (white), 2 PET (household chemicals)s, 2 PND (household chemicals)s, 1 Other plastic (transparent), 37.3ms
# Speed: 2.0ms preprocess, 37.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (blue), 1 PET (white), 2 PET (household chemicals)s, 2 PND (household chemicals)s, 1 Other plastic (transparent), 36.1ms
# Speed: 2.0ms preprocess, 36.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (blue), 1 PET (white), 2 PET (household chemicals)s, 2 PND (household chemicals)s, 1 Other plastic (transparent), 36.0ms
# Speed: 3.0ms preprocess, 36.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (blue), 1 PET (white), 2 PET (household chemicals)s, 2 PND (household chemicals)s, 34.8ms
# Speed: 3.0ms preprocess, 34.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (blue), 1 PET (white), 2 PET (household chemicals)s, 2 PND (household chemicals)s, 35.5ms
# Speed: 2.0ms preprocess, 35.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (blue), 1 PET (transparent), 1 PET (white), 2 PET (household chemicals)s, 1 PND (household chemicals), 36.1ms
# Speed: 2.0ms preprocess, 36.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (blue), 1 PET (transparent), 1 PET (white), 2 PET (household chemicals)s, 1 PND (household chemicals), 34.5ms
# Speed: 3.1ms preprocess, 34.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (blue), 1 PET (transparent), 1 PET (white), 2 PET (household chemicals)s, 1 PND (household chemicals), 35.8ms
# Speed: 3.0ms preprocess, 35.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent), 1 PET (white), 2 PET (household chemicals)s, 1 PND (household chemicals), 36.5ms
# Speed: 2.0ms preprocess, 36.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent), 1 PET (white), 2 PET (household chemicals)s, 1 PND (household chemicals), 36.5ms
# Speed: 2.0ms preprocess, 36.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent), 1 PET (white), 2 PET (household chemicals)s, 1 PND (household chemicals), 36.1ms
# Speed: 2.7ms preprocess, 36.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent), 1 PET (white), 1 PET (household chemicals), 1 PND (household chemicals), 36.0ms
# Speed: 3.5ms preprocess, 36.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent), 1 PET (white), 1 PET (household chemicals), 1 PND (household chemicals), 35.4ms
# Speed: 3.0ms preprocess, 35.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent), 1 PET (white), 1 PET (household chemicals), 1 PND (household chemicals), 35.6ms
# Speed: 3.0ms preprocess, 35.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent), 1 PET (white), 1 PET (household chemicals), 1 PND (household chemicals), 36.4ms
# Speed: 3.0ms preprocess, 36.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent), 1 PET (white), 1 PET (household chemicals), 1 PND (household chemicals), 34.7ms
# Speed: 3.0ms preprocess, 34.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent), 1 PET (white), 1 PET (household chemicals), 1 PND (household chemicals), 36.5ms
# Speed: 3.0ms preprocess, 36.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (transparent), 1 PET (white), 1 PET (household chemicals), 1 PND (household chemicals), 37.2ms
# Speed: 2.0ms preprocess, 37.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (transparent), 1 PET (transparent) (dark blue), 1 PET (white), 1 PET (household chemicals), 1 PND (household chemicals), 35.5ms
# Speed: 3.0ms preprocess, 35.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (transparent), 1 PET (transparent) (dark blue), 2 PET (white)s, 1 PET (household chemicals), 34.9ms
# Speed: 3.0ms preprocess, 34.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (transparent), 1 PET (transparent) (dark blue), 2 PET (white)s, 1 PET (household chemicals), 36.9ms
# Speed: 2.6ms preprocess, 36.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (transparent), 1 PET (transparent) (dark blue), 2 PET (white)s, 1 PET (household chemicals), 37.1ms
# Speed: 3.1ms preprocess, 37.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (transparent), 1 PET (transparent) (dark blue), 2 PET (white)s, 1 PET (household chemicals), 36.2ms
# Speed: 2.0ms preprocess, 36.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent) (brown)s, 1 PET (transparent), 2 PET (white)s, 1 PET (household chemicals), 36.6ms
# Speed: 2.0ms preprocess, 36.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent) (brown)s, 1 PET (transparent), 2 PET (white)s, 36.9ms
# Speed: 2.0ms preprocess, 36.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent) (brown)s, 1 PET (transparent), 1 PET (transparent) (dark blue), 2 PET (white)s, 36.4ms
# Speed: 2.5ms preprocess, 36.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent) (brown)s, 1 PET (transparent), 2 PET (transparent) (dark blue)s, 1 PET (white), 36.1ms
# Speed: 3.0ms preprocess, 36.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent) (brown)s, 1 PET (transparent), 2 PET (transparent) (dark blue)s, 1 PET (white), 36.7ms
# Speed: 2.0ms preprocess, 36.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent) (brown)s, 1 PET (transparent), 2 PET (transparent) (dark blue)s, 1 PET (white), 35.1ms
# Speed: 2.0ms preprocess, 35.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent) (brown)s, 1 PET (transparent), 2 PET (transparent) (dark blue)s, 1 PET (white), 36.5ms
# Speed: 2.0ms preprocess, 36.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent) (brown)s, 1 PET (transparent), 2 PET (transparent) (dark blue)s, 1 PET (white), 36.7ms
# Speed: 3.0ms preprocess, 36.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent) (brown)s, 1 PET (transparent), 2 PET (transparent) (dark blue)s, 1 PET (white), 35.2ms
# Speed: 3.0ms preprocess, 35.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent) (brown)s, 1 PET (transparent), 2 PET (transparent) (dark blue)s, 1 PET (white), 36.6ms
# Speed: 2.0ms preprocess, 36.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent) (brown)s, 1 PET (transparent), 2 PET (transparent) (dark blue)s, 1 PET (white), 36.2ms
# Speed: 3.2ms preprocess, 36.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent) (brown)s, 1 PET (transparent), 2 PET (transparent) (dark blue)s, 1 PET (white), 38.3ms
# Speed: 2.0ms preprocess, 38.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent) (brown)s, 2 PET (transparent) (dark blue)s, 1 PET (white), 41.1ms
# Speed: 2.7ms preprocess, 41.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent) (brown)s, 2 PET (transparent) (dark blue)s, 1 PET (white), 38.8ms
# Speed: 3.0ms preprocess, 38.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent) (brown)s, 2 PET (transparent) (dark blue)s, 1 PET (white), 38.4ms
# Speed: 3.2ms preprocess, 38.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (transparent) (brown)s, 2 PET (transparent) (dark blue)s, 1 PET (white), 36.1ms
# Speed: 3.1ms preprocess, 36.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (transparent) (brown)s, 2 PET (transparent) (dark blue)s, 1 PET (white), 35.4ms
# Speed: 3.0ms preprocess, 35.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (transparent) (brown)s, 2 PET (transparent) (dark blue)s, 1 PET (white), 36.6ms
# Speed: 2.0ms preprocess, 36.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (transparent) (brown)s, 2 PET (transparent) (dark blue)s, 1 PET (white), 35.5ms
# Speed: 2.5ms preprocess, 35.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (transparent) (brown)s, 2 PET (transparent) (dark blue)s, 1 PET (white), 36.8ms
# Speed: 3.0ms preprocess, 36.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (transparent) (brown)s, 2 PET (transparent) (dark blue)s, 1 PET (white), 38.4ms
# Speed: 3.0ms preprocess, 38.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 2 PET (transparent) (dark blue)s, 1 PET (white), 35.9ms
# Speed: 2.6ms preprocess, 35.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 2 PET (transparent) (dark blue)s, 1 PET (white), 36.3ms
# Speed: 2.0ms preprocess, 36.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (transparent) (dark blue), 1 PET (white), 36.1ms
# Speed: 3.0ms preprocess, 36.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (dark blue), 36.8ms
# Speed: 3.0ms preprocess, 36.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (dark blue), 36.3ms
# Speed: 3.1ms preprocess, 36.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (dark blue), 35.9ms
# Speed: 3.0ms preprocess, 35.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 38.9ms
# Speed: 2.0ms preprocess, 38.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 35.9ms
# Speed: 3.3ms preprocess, 35.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 37.2ms
# Speed: 2.0ms preprocess, 37.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 36.6ms
# Speed: 3.0ms preprocess, 36.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 36.1ms
# Speed: 2.0ms preprocess, 36.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 35.9ms
# Speed: 3.0ms preprocess, 35.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 34.7ms
# Speed: 2.5ms preprocess, 34.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 36.0ms
# Speed: 2.0ms preprocess, 36.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 36.2ms
# Speed: 2.0ms preprocess, 36.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 37.2ms
# Speed: 3.0ms preprocess, 37.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 35.8ms
# Speed: 3.0ms preprocess, 35.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 38.4ms
# Speed: 3.0ms preprocess, 38.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 36.7ms
# Speed: 2.0ms preprocess, 36.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 35.9ms
# Speed: 3.0ms preprocess, 35.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 36.7ms
# Speed: 3.0ms preprocess, 36.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 37.1ms
# Speed: 2.0ms preprocess, 37.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 35.7ms
# Speed: 3.0ms preprocess, 35.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 35.9ms
# Speed: 2.0ms preprocess, 35.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 35.2ms
# Speed: 3.0ms preprocess, 35.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 37.2ms
# Speed: 3.0ms preprocess, 37.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 36.8ms
# Speed: 2.5ms preprocess, 36.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 35.7ms
# Speed: 2.0ms preprocess, 35.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 Other plastic (transparent), 36.8ms
# Speed: 3.0ms preprocess, 36.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 Other plastic (transparent), 36.4ms
# Speed: 2.0ms preprocess, 36.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 Other plastic (transparent), 34.6ms
# Speed: 3.0ms preprocess, 34.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 Other plastic (transparent), 37.9ms
# Speed: 2.7ms preprocess, 37.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 Other plastic (transparent), 36.5ms
# Speed: 2.0ms preprocess, 36.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 Other plastic (transparent), 35.6ms
# Speed: 3.0ms preprocess, 35.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 Other plastic (transparent), 37.6ms
# Speed: 3.0ms preprocess, 37.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (transparent) (dark blue), 1 Other plastic, 1 Other plastic (transparent), 40.2ms
# Speed: 2.0ms preprocess, 40.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (transparent) (dark blue), 1 Other plastic, 1 Other plastic (transparent), 38.7ms
# Speed: 3.0ms preprocess, 38.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (transparent) (dark blue), 1 Other plastic, 1 Other plastic (transparent), 36.2ms
# Speed: 3.0ms preprocess, 36.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (transparent) (dark blue), 1 Other plastic, 1 Other plastic (transparent), 36.6ms
# Speed: 3.0ms preprocess, 36.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (transparent) (dark blue), 1 Other plastic, 1 Other plastic (transparent), 38.1ms
# Speed: 3.0ms preprocess, 38.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (transparent) (dark blue), 1 Other plastic, 1 Other plastic (transparent), 35.8ms
# Speed: 2.0ms preprocess, 35.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (transparent) (dark blue), 1 Other plastic, 1 Other plastic (transparent), 36.2ms
# Speed: 3.0ms preprocess, 36.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (transparent) (dark blue), 1 Other plastic, 1 Other plastic (transparent), 37.0ms
# Speed: 2.0ms preprocess, 37.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (dark blue), 1 Other plastic, 1 Other plastic (transparent), 37.5ms
# Speed: 2.0ms preprocess, 37.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (dark blue), 1 Other plastic, 1 Other plastic (transparent), 36.0ms
# Speed: 3.0ms preprocess, 36.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (dark blue), 1 Other plastic, 1 Other plastic (transparent), 36.3ms
# Speed: 2.0ms preprocess, 36.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (dark blue), 1 Other plastic, 1 Other plastic (transparent), 36.2ms
# Speed: 2.0ms preprocess, 36.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (dark blue), 1 Other plastic, 1 Other plastic (transparent), 36.8ms
# Speed: 2.0ms preprocess, 36.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (dark blue), 1 Other plastic, 1 Other plastic (transparent), 35.1ms
# Speed: 3.0ms preprocess, 35.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (dark blue), 1 Other plastic, 1 Other plastic (transparent), 36.6ms
# Speed: 2.0ms preprocess, 36.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (dark blue), 1 Other plastic, 1 Other plastic (transparent), 38.1ms
# Speed: 2.0ms preprocess, 38.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (dark blue), 1 Other plastic, 1 Other plastic (transparent), 36.3ms
# Speed: 3.0ms preprocess, 36.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (dark blue), 1 Other plastic, 1 Other plastic (transparent), 35.7ms
# Speed: 3.0ms preprocess, 35.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent), 1 PET (transparent) (dark blue), 1 Other plastic, 1 Other plastic (transparent), 35.4ms
# Speed: 3.0ms preprocess, 35.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent), 1 PET (transparent) (dark blue), 1 Other plastic, 35.6ms
# Speed: 3.0ms preprocess, 35.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent)s, 1 PET (transparent) (dark blue), 1 Other plastic, 36.5ms
# Speed: 2.0ms preprocess, 36.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent)s, 1 PET (transparent) (dark blue), 1 Other plastic, 36.6ms
# Speed: 2.0ms preprocess, 36.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent)s, 1 PET (transparent) (dark blue), 1 PET (white), 1 Other plastic, 36.2ms
# Speed: 2.0ms preprocess, 36.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent)s, 1 PET (transparent) (dark blue), 1 PET (white), 1 Other plastic, 35.2ms
# Speed: 3.0ms preprocess, 35.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent)s, 1 PET (transparent) (dark blue), 2 PET (white)s, 1 Other plastic, 36.3ms
# Speed: 2.0ms preprocess, 36.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent)s, 1 PET (transparent) (dark blue), 2 PET (white)s, 1 Other plastic, 35.0ms
# Speed: 3.0ms preprocess, 35.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# ...
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (household chemicals), 34.2ms
# Speed: 3.0ms preprocess, 34.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (household chemicals), 34.0ms
# Speed: 2.0ms preprocess, 34.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (household chemicals), 34.1ms
# Speed: 2.0ms preprocess, 34.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (household chemicals), 34.0ms
# Speed: 3.0ms preprocess, 34.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (household chemicals), 33.0ms
# Speed: 2.0ms preprocess, 33.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (household chemicals), 35.2ms
# Speed: 3.0ms preprocess, 35.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (household chemicals), 34.0ms
# Speed: 3.0ms preprocess, 34.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (household chemicals), 47.0ms
# Speed: 3.0ms preprocess, 47.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (household chemicals), 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (household chemicals), 34.0ms
# Speed: 2.0ms preprocess, 34.0ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (household chemicals), 39.9ms
# Speed: 3.0ms preprocess, 39.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (household chemicals), 39.8ms
# Speed: 2.0ms preprocess, 39.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (household chemicals), 37.2ms
# Speed: 3.0ms preprocess, 37.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (household chemicals), 34.7ms
# Speed: 2.0ms preprocess, 34.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (household chemicals), 33.2ms
# Speed: 2.0ms preprocess, 33.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (household chemicals), 34.7ms
# Speed: 3.0ms preprocess, 34.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent), 1 PET (household chemicals), 33.7ms
# Speed: 2.0ms preprocess, 33.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (transparent), 1 PET (household chemicals), 34.5ms
# Speed: 2.0ms preprocess, 34.5ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (transparent), 1 PET (household chemicals), 34.0ms
# Speed: 2.0ms preprocess, 34.0ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (transparent), 1 PET (household chemicals), 34.0ms
# Speed: 3.0ms preprocess, 34.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (transparent), 1 PET (household chemicals), 34.0ms
# Speed: 2.0ms preprocess, 34.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (transparent), 1 PET (household chemicals), 34.2ms
# Speed: 3.0ms preprocess, 34.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (transparent), 1 PET (household chemicals), 34.0ms
# Speed: 2.0ms preprocess, 34.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (transparent), 33.0ms
# Speed: 2.0ms preprocess, 33.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent) (green)s, 1 PET (transparent) (brown), 1 PET (transparent), 34.3ms
# Speed: 3.0ms preprocess, 34.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent) (green)s, 1 PET (transparent) (brown), 1 PET (transparent), 33.0ms
# Speed: 2.0ms preprocess, 33.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent) (green)s, 1 PET (transparent) (brown), 1 PET (transparent), 35.1ms
# Speed: 2.0ms preprocess, 35.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent) (green)s, 1 PET (transparent) (brown), 1 PET (transparent), 35.0ms
# Speed: 3.0ms preprocess, 35.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent) (green)s, 1 PET (transparent) (brown), 1 PET (transparent), 1 PET (white), 34.0ms
# Speed: 2.0ms preprocess, 34.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent) (green)s, 1 PET (transparent) (brown), 1 PET (transparent), 1 PET (white), 1 Not plastic, 32.0ms
# Speed: 3.0ms preprocess, 32.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent) (green)s, 1 PET (transparent) (brown), 1 PET (transparent), 1 PET (white), 1 Not plastic, 32.0ms
# Speed: 3.0ms preprocess, 32.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent) (green)s, 1 PET (transparent) (brown), 1 PET (transparent), 1 PET (white), 33.6ms
# Speed: 3.0ms preprocess, 33.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 2 PET (transparent)s, 1 PET (white), 33.9ms
# Speed: 2.0ms preprocess, 33.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 2 PET (transparent)s, 1 PET (white), 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 2 PET (transparent)s, 1 PET (white), 34.7ms
# Speed: 2.0ms preprocess, 34.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (transparent)s, 1 PET (white), 32.6ms
# Speed: 3.0ms preprocess, 32.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (transparent)s, 1 PET (white), 33.0ms
# Speed: 2.0ms preprocess, 33.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (transparent)s, 1 PET (white), 35.0ms
# Speed: 2.0ms preprocess, 35.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (transparent)s, 1 PET (white), 34.1ms
# Speed: 3.0ms preprocess, 34.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (transparent)s, 1 PET (white), 34.6ms
# Speed: 2.0ms preprocess, 34.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (transparent)s, 1 PET (white), 33.5ms
# Speed: 2.0ms preprocess, 33.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 3 PET (transparent)s, 1 PET (white), 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 3 PET (transparent)s, 1 PET (white), 35.8ms
# Speed: 2.0ms preprocess, 35.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (transparent)s, 1 PET (white), 33.0ms
# Speed: 1.5ms preprocess, 33.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (transparent)s, 1 PET (white), 1 Other plastic, 33.4ms
# Speed: 2.0ms preprocess, 33.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (transparent)s, 1 PET (white), 1 Other plastic, 34.6ms
# Speed: 2.0ms preprocess, 34.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (transparent)s, 1 PET (white), 1 Other plastic, 33.1ms
# Speed: 3.0ms preprocess, 33.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (transparent)s, 1 PET (white), 1 Other plastic, 35.0ms
# Speed: 2.0ms preprocess, 35.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 2 PET (transparent)s, 1 PET (white), 2 Other plastics, 35.1ms
# Speed: 2.0ms preprocess, 35.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent), 1 PET (white), 2 Other plastics, 38.8ms
# Speed: 2.8ms preprocess, 38.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent)s, 1 PET (white), 2 Other plastics, 38.4ms
# Speed: 2.5ms preprocess, 38.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent)s, 1 PET (white), 2 Other plastics, 38.9ms
# Speed: 2.0ms preprocess, 38.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent)s, 1 PET (white), 2 Other plastics, 34.0ms
# Speed: 2.0ms preprocess, 34.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 2 PET (transparent)s, 1 PET (white), 2 Other plastics, 1 Not plastic, 35.2ms
# Speed: 3.0ms preprocess, 35.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 2 PET (transparent)s, 1 PET (white), 2 Other plastics, 38.9ms
# Speed: 2.0ms preprocess, 38.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 2 PET (transparent)s, 2 Other plastics, 34.3ms
# Speed: 3.0ms preprocess, 34.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 2 PET (transparent)s, 2 Other plastics, 34.9ms
# Speed: 2.0ms preprocess, 34.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 2 PET (transparent)s, 2 Other plastics, 34.5ms
# Speed: 3.0ms preprocess, 34.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (transparent), 2 Other plastics, 33.1ms
# Speed: 2.0ms preprocess, 33.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (transparent), 2 Other plastics, 33.3ms
# Speed: 2.0ms preprocess, 33.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (transparent), 2 Other plastics, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (transparent), 2 Other plastics, 35.0ms
# Speed: 2.0ms preprocess, 35.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 1 PET (transparent), 2 Other plastics, 32.0ms
# Speed: 3.0ms preprocess, 32.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (transparent), 2 Other plastics, 34.0ms
# Speed: 2.0ms preprocess, 34.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (transparent), 2 Other plastics, 35.1ms
# Speed: 3.0ms preprocess, 35.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (transparent), 2 Other plastics, 33.7ms
# Speed: 3.0ms preprocess, 33.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (transparent), 2 Other plastics, 34.1ms
# Speed: 2.7ms preprocess, 34.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (transparent), 2 Other plastics, 34.0ms
# Speed: 2.0ms preprocess, 34.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (transparent), 2 Other plastics, 34.6ms
# Speed: 3.0ms preprocess, 34.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (transparent), 2 Other plastics, 33.9ms
# Speed: 2.0ms preprocess, 33.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 PET (transparent), 1 Other plastic, 34.0ms
# Speed: 2.0ms preprocess, 34.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (green), 1 PET (transparent) (brown), 1 Other plastic, 34.0ms
# Speed: 3.0ms preprocess, 34.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PET (transparent) (brown), 34.3ms
# Speed: 3.0ms preprocess, 34.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent) (green)s, 1 PET (transparent) (brown), 31.7ms
# Speed: 3.0ms preprocess, 31.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent) (green)s, 1 PET (transparent) (brown), 34.0ms
# Speed: 2.0ms preprocess, 34.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent) (green)s, 1 PET (transparent) (brown), 36.8ms
# Speed: 2.0ms preprocess, 36.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent) (green)s, 1 PET (transparent) (brown), 34.0ms
# Speed: 2.0ms preprocess, 34.0ms inference, 9.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent) (green)s, 2 PET (transparent) (brown)s, 32.0ms
# Speed: 3.1ms preprocess, 32.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent) (green)s, 2 PET (transparent) (brown)s, 32.0ms
# Speed: 3.0ms preprocess, 32.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent) (green)s, 2 PET (transparent) (brown)s, 34.0ms
# Speed: 3.0ms preprocess, 34.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 PET (transparent) (green)s, 1 PET (transparent) (brown), 32.0ms
# Speed: 3.0ms preprocess, 32.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Статистика обработки:
# Количество обработанных кадров: 9000
# Общее время обработки: 1141.70 секунд
# Среднее время обработки одного кадра: 126.86 мс
#
# Видео с трекингом сохранено в output_tracked_video.mp4
# Результаты трекинга сохранены в mot_results.txt

# %%
# Функция для загрузки данных из файла в формат motmetrics
def load_mot_results(path, max_frames=100):
    data = {}
    with open(path, 'r') as f:
        for line in f.readlines():
            frame_id, track_id, x, y, w, h, _, _, _ = map(float, line.strip().split(','))
            frame_id = int(frame_id)
            if frame_id > max_frames:
                break
            if frame_id not in data:
                data[frame_id] = []
            # Преобразование координат в формат (ID, x_center, y_center, width, height)
            data[frame_id].append((track_id, x + w / 2, y + h / 2, w, h))
    return data

# Загрузка данных из файлов
gt_data = load_mot_results(path_to_gt, max_frames=number_frames)
tracker_data = load_mot_results(path_to_tracker_results, max_frames=number_frames)

# Инициализация аккумулятора
acc = mm.MOTAccumulator(auto_id=True)

# Сопоставление GT и результатов трекинга по кадрам
for frame_id in range(1, 9001):  # Первые 100 кадров
    gt_frame = gt_data.get(frame_id, [])
    tracker_frame = tracker_data.get(frame_id, [])
    
    # Разделяем данные по идентификаторам и координатам
    gt_ids, gt_points = zip(*[(d[0], (d[1], d[2])) for d in gt_frame]) if gt_frame else ([], [])
    tracker_ids, tracker_points = zip(*[(d[0], (d[1], d[2])) for d in tracker_frame]) if tracker_frame else ([], [])

    # Вычисляем расстояния между треками и GT 
    distances = mm.distances.norm2squared_matrix(gt_points, tracker_points, max_d2=10000)
    
    # Обновляем аккумулятор с текущими данными
    acc.update(gt_ids, tracker_ids, distances)

# Вычисление метрик
mh = mm.metrics.create()
summary = mh.compute(acc, metrics=['mota', 'motp', 'idf1', 'precision', 'recall'], name='acc')

# %%
summary
# Out:
#          mota        motp     idf1  precision    recall
# acc  0.923127  233.051184  0.93893   0.996594  0.930562

# %%
print(f'''avg per frame {avg_time_per_frame * 1000:.2f}
frame total {frame_count}
''')
# Out:
# avg per frame 126.86
# frame total 9000
